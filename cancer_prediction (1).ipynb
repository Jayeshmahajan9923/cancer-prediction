# %% [markdown]
# # 🧠 Cancer Prediction using Machine Learning
#
# This notebook contains a complete end-to-end machine learning pipeline to predict whether breast tumors are **malignant** (cancerous, `1`) or **benign** (non-cancerous, `0`).
#
# ## Key Production-Grade Features Implemented:
# 1. **Data Leakage Prevention**: Features are scaled *after* the train-test split, fitting the scaler only on the training subset.
# 2. **Stratified K-Fold Cross-Validation**: Ensures target class ratios are preserved across all folds during cross-validation.
# 3. **GridSearchCV**: Systematically tunes hyperparameters for both Random Forest and Support Vector Machine models.
# 4. **Clinical Evaluation Metrics**: Beyond raw accuracy, we evaluate models using **Recall** (vital for medical diagnosis to minimize false negatives), **Precision-Recall Curves**, and **ROC-AUC Curves**.
# 5. **Feature Importance Visualizations**: Explains which biological features are driving the Random Forest predictions.
# 6. **Model Serialization**: Automatically saves the best-performing model and scaler for deployment.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Machine learning models and preprocessing
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# Metrics for evaluation
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report, roc_curve, auc,
    precision_recall_curve, average_precision_score, roc_auc_score
)

# Utilities
import joblib
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 1: Loading and Exploring the Dataset
# We load the dataset using a relative path so that anyone cloning this repository can run the code immediately. We then inspect the first 5 records and general metadata.

# %%
# Load the dataset using a relative path
data = pd.read_csv("data (1).csv")

# Print dataframe information and dimensions
print(f"Dataset Dimensions: {data.shape[0]} rows, {data.shape[1]} columns\n")
print(data.info())
data.head()

# %% [markdown]
# ## Step 2: Target Encoding
# The target label `diagnosis` is stored as text: `M` (Malignant) and `B` (Benign). We encode these into numeric values where Malignant is `1` (positive class) and Benign is `0` (negative class).

# %%
# Categorize target column: M -> 1 (Malignant), B -> 0 (Benign)
data['diagnosis'] = data['diagnosis'].map({'M': 1, 'B': 0})
print("Class distribution:\n", data['diagnosis'].value_counts(normalize=True))

# %% [markdown]
# ## Step 3: Splitting Train and Test Sets
# We drop identifier column `id` and the target column `diagnosis` to isolate features `X`. We then split the data into 80% training and 20% testing.
#
# **Stratification**: We pass `stratify=Y` to preserve target class proportions across the train and test subsets.

# %%
X = data.drop(["diagnosis", "id"], axis=1)
Y = data["diagnosis"]

# Split with stratification and fixed random state for reproducibility
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, stratify=Y, random_state=42
)

# %% [markdown]
# ## Step 4: Feature Scaling
# Algorithms like Support Vector Machines rely on distance computations. Because feature dimensions differ by orders of magnitude (e.g. `area_mean` is up to 2500, while `smoothness_mean` is ~0.1), scaling is essential.
#
# **Preventing Data Leakage**: We fit the `StandardScaler` only on the training set, then transform both the training and testing sets.

# %%
scaler = StandardScaler()

# Fit on training features and scale both subsets
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convert back to pandas DataFrame for feature name access later
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X.columns)

# %% [markdown]
# ## Step 5: Designing a Reusable Model Evaluation Pipeline
# To remove duplicate code, we build a comprehensive function to print metric reports and plot 4 graphs:
# 1. **Confusion Matrix Heatmap**: Displays true positives, true negatives, false positives, and false negatives.
# 2. **ROC Curve (Receiver Operating Characteristic)**: Visualizes trade-off between True Positive Rate and False Positive Rate, displaying the Area Under the Curve (AUC) score.
# 3. **Precision-Recall Curve**: Evaluates performance under potential class imbalance.
# 4. **Feature Importance Plot (Optional)**: If the classifier supports it (like Random Forest), shows the relative impact of each clinical attribute.

# %%
def evaluate_model(model, X_train, Y_train, X_test, Y_test, model_name, feature_names=None):
    """
    Trains/evaluates the given model, outputs classification metrics, and plots evaluation curves.
    """
    # Predict class labels
    y_pred = model.predict(X_test)
    
    # Predict probabilities (needed for ROC and PR curves)
    if hasattr(model, "predict_proba"):
        y_proba = model.predict_proba(X_test)[:, 1]
    else:
        y_proba = model.decision_function(X_test)
        
    # Compute metrics
    acc = accuracy_score(Y_test, y_pred)
    prec = precision_score(Y_test, y_pred)
    rec = recall_score(Y_test, y_pred)
    f1 = f1_score(Y_test, y_pred)
    roc_auc = roc_auc_score(Y_test, y_proba)
    
    print(f"==================== {model_name} ====================")
    print(f"Accuracy  : {acc:.4%}")
    print(f"Precision : {prec:.4%}")
    print(f"Recall    : {rec:.4%} (CRITICAL FOR CANCER DETECTION!)")
    print(f"F1-Score  : {f1:.4%}")
    print(f"ROC-AUC   : {roc_auc:.4%}\n")
    print("Classification Report:\n", classification_report(Y_test, y_pred))
    
    # Setup multi-panel plotting
    has_importances = hasattr(model, "feature_importances_")
    num_plots = 4 if (has_importances and feature_names is not None) else 3
    fig, axes = plt.subplots(1, num_plots, figsize=(6 * num_plots, 5))
    
    # 1. Confusion Matrix
    cm = confusion_matrix(Y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[0])
    axes[0].set_xlabel('Predicted Label')
    axes[0].set_ylabel('True Label')
    axes[0].set_title(f'{model_name} Confusion Matrix')
    
    # 2. ROC Curve
    fpr, tpr, _ = roc_curve(Y_test, y_proba)
    axes[1].plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC AUC: {roc_auc:.4f}')
    axes[1].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    axes[1].set_xlabel('False Positive Rate')
    axes[1].set_ylabel('True Positive Rate')
    axes[1].set_title(f'{model_name} ROC Curve')
    axes[1].legend(loc="lower right")
    
    # 3. Precision-Recall Curve
    precision, recall, _ = precision_recall_curve(Y_test, y_proba)
    avg_prec = average_precision_score(Y_test, y_proba)
    axes[2].plot(recall, precision, color='green', lw=2, label=f'AP Score: {avg_prec:.4f}')
    axes[2].set_xlabel('Recall')
    axes[2].set_ylabel('Precision')
    axes[2].set_title(f'{model_name} Precision-Recall Curve')
    axes[2].legend(loc="lower left")
    
    # 4. Feature Importance (if supported)
    if num_plots == 4:
        importances = model.feature_importances_
        indices = np.argsort(importances)[::-1]
        top_features = 10
        axes[3].bar(range(top_features), importances[indices[:top_features]], color='teal')
        axes[3].set_xticks(range(top_features))
        axes[3].set_xticklabels([feature_names[i] for i in indices[:top_features]], rotation=45, ha='right')
        axes[3].set_title(f'{model_name} Top 10 Features')
        
    plt.tight_layout()
    plt.show()
    
    return {
        'Model': model_name,
        'Accuracy': acc,
        'Precision': prec,
        'Recall': rec,
        'F1-Score': f1,
        'ROC-AUC': roc_auc
    }

# %% [markdown]
# ## Step 6: Random Forest - GridSearchCV Tuning
# We set up hyperparameter optimization using GridSearchCV combined with a 5-fold Stratified K-Fold. The search optimizes for **Recall** to prioritize minimizing false negatives.

# %%
# Define Stratified K-Fold validation framework
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Param grid for Random Forest
rf_param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [5, 10, None],
    'min_samples_split': [2, 5, 10]
}

rf_grid = GridSearchCV(
    estimator=RandomForestClassifier(random_state=42),
    param_grid=rf_param_grid,
    cv=cv,
    scoring='recall',  # Optimize for high Recall
    n_jobs=-1
)

# Fit grid search on training data
rf_grid.fit(X_train, Y_train)  # Tree models don't strictly require scaling
print("Best Random Forest Params:", rf_grid.best_params_)

# Evaluate
rf_metrics = evaluate_model(
    rf_grid.best_estimator_, X_train, Y_train, X_test, Y_test, 
    "Random Forest (Tuned)", feature_names=X.columns
)

# %% [markdown]
# ## Step 7: SVM - GridSearchCV Tuning
# Now we run a parameter sweep for the Support Vector Classifier. We enable `probability=True` on SVC so we can compute predicted class probabilities for the ROC/PR metrics.

# %%
# Param grid for SVC
svm_param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.01, 0.1],
    'kernel': ['rbf', 'linear']
}

svm_grid = GridSearchCV(
    estimator=SVC(probability=True, random_state=42),
    param_grid=svm_param_grid,
    cv=cv,
    scoring='recall',
    n_jobs=-1
)

# Fit SVM on SCALED training data
svm_grid.fit(X_train_scaled, Y_train)
print("Best SVM Params:", svm_grid.best_params_)

# Evaluate
svm_metrics = evaluate_model(
    svm_grid.best_estimator_, X_train_scaled, Y_train, X_test_scaled, Y_test, 
    "SVM (Tuned)"
)

# %% [markdown]
# ## Step 8: Model Comparison
# Let's compare the metrics computed by our model pipeline function to select the best estimator.

# %%
comparison_df = pd.DataFrame([rf_metrics, svm_metrics])
# Apply styling for visualization
comparison_df.style.highlight_max(subset=['Accuracy', 'Recall', 'ROC-AUC'], color='lightgreen')

# %% [markdown]
# ## Step 9: Save the Best Model for Production
# We identify the best-performing model based on Recall and ROC-AUC. We then serialize the model object alongside the fitted `StandardScaler` using `joblib` so both pre-processing and prediction can run concurrently in production.

# %%
# Select best model (SVM is generally highly performant once scaled and tuned)
best_model = svm_grid.best_estimator_

# Bundle model and scaler
production_pipeline = {
    'scaler': scaler,
    'model': best_model
}

# Save objects using joblib
model_filename = 'cancer_prediction_pipeline.joblib'
joblib.dump(production_pipeline, model_filename)
print(f"Successfully saved production pipeline to: '{model_filename}'")

# Quick demonstration: loading pipeline and predicting a sample record
loaded_pipeline = joblib.load(model_filename)
sample_scaled = loaded_pipeline['scaler'].transform(X_test.iloc[[0]])
prediction = loaded_pipeline['model'].predict(sample_scaled)
print(f"Sample Ground Truth: {Y_test.iloc[0]} | Pipeline Prediction: {prediction[0]}")
